# %% [markdown]
# ## Load the data

# %%
suppressWarnings(suppressMessages(library(tidyverse)))
suppressWarnings(suppressMessages(library(gridExtra)))
suppressWarnings(suppressMessages(library(memisc)))
library(emmeans)

# Load the data
load("~/Documents/holding_gwu_dissertation/data/vcf_data.RData")
paste0("Initial sample: ", nrow(vcf_data))
# Out:
# [1] "Initial sample: 507"

# %% [markdown]
# ### Impute vaccinated onto intentions scale

# %%
# Add a "vaccinated" response to intentions that has a value of 8
vcf_data$base_intention <-  factor(vcf_data$base_intention, 
                                levels = c(levels(vcf_data$base_intention),
                                           "Vaccinated"))
vcf_data$intention_2 <-  factor(vcf_data$intention_2, 
                                levels = c(levels(vcf_data$intention_2),
                                           "Vaccinated"))
vcf_data$intention_4 <-  factor(vcf_data$intention_4, 
                                levels = c(levels(vcf_data$intention_4),
                                           "Vaccinated"))
vcf_data$intention_6 <-  factor(vcf_data$intention_6, 
                                levels = c(levels(vcf_data$intention_6),
                                           "Vaccinated"))

# Recode intentions for vaccinated people as a vaccinated (8) response
vcf_data$intention_2[vcf_data$vax_y_n_2 == "Yes"] <- "Vaccinated"
vcf_data$intention_4[vcf_data$vax_y_n_4 == "Yes"] <- "Vaccinated"
vcf_data$intention_6[vcf_data$vax_y_n_6 == "Yes"] <- "Vaccinated"

# %% [markdown]
# ### Remove people who didn't follow up

# %%
failed_to_follow_up <- vcf_data %>% filter(is.na(sp_confidence_6))
subset <- vcf_data %>% filter(!is.na(sp_confidence_6))
paste0("Dropped for follow-up: ", nrow(failed_to_follow_up), " (", 
       round(nrow(failed_to_follow_up)/nrow(vcf_data),3), ")")
paste0("Analysis Sample: ", nrow(subset))
# Out:
# [1] "Dropped for follow-up: 76 (0.15)"
# [1] "Analysis Sample: 431"

# %% [markdown]
# ### Remove people who weren't paying attention

# %%
not_paying_attention <- subset %>% filter(attention2_6 != "Somewhat Agree",
                                               !(vcf_data$partic %in% failed_to_follow_up$mturk_code))

subset <- vcf_data %>% filter(!is.na(sp_confidence_6), attention2_6 == "Somewhat Agree")
paste0("Dropped for attention-up: ", nrow(not_paying_attention), " (", 
       round(nrow(not_paying_attention)/nrow(vcf_data),3), ")")
paste0("Analysis Sample: ", nrow(subset))
# Out:
# Error in `filter()`:
# ! Problem while computing `..2 = !(vcf_data$participant_id %in%
#   failed_to_follow_up$participant_id)`.
# ✖ Input `..2` must be of size 431 or 1, not size 507.
# Traceback:
#
# 1. subset %>% filter(attention2_6 != "Somewhat Agree", !(vcf_data$participant_id %in%
#  .     failed_to_follow_up$participant_id))
# 2. filter(., attention2_6 != "Somewhat Agree", !(vcf_data$participant_id %in%
#  .     failed_to_follow_up$participant_id))
# 3. filter.data.frame(., attention2_6 != "Somewhat Agree", !(vcf_data$participant_id %in%
#  .     failed_to_follow_up$participant_id))
# 4. filter_rows(.data, ..., caller_env = caller_env())
# 5. filter_eval(dots, mask = mask, error_call = error_call)
# 6. withCallingHandlers({
#  .     mask$eval_all_filter(dots, env_filter)
#  . }, error = function(e) {
#  .     local_error_context(dots = dots, .index = env_filter$current_expression,
#  .         mask = mask)
# ...

# %% [markdown]
# ### Remove people who explicitly stated they were vaccinated prior to the study

# %%
vaccinated_prior <- subset %>% filter(
    (vaccinated_prior == TRUE & vax_y_n_2 == "Was already vaccinated prior to joining the study") |
    mturk_code == "521706")
subset <- subset[!(subset$mturk_code %in% vaccinated_prior$mturk_code), ]

paste0("Dropped for explicitly stating they were vaccinated prior to the study: ", nrow(vaccinated_prior), " (", 
       round(nrow(vaccinated_prior)/nrow(vcf_data),3), ")")
paste0("Analysis Sample: ", nrow(subset))

vaccinated_prior %>% filter(mturk_code != "521706") %>% 
    dplyr::select(base_intention, doses_2, doses_4, doses_6, vax_y_n_2)
vaccinated_prior %>% filter(mturk_code == "521706") %>% 
    dplyr::select(base_intention, intention_6, addressed_concerns_text_6)
# Out:
# [1] "Dropped for explicitly stating they were vaccinated prior to the study: 21 (0.041)"
# [1] "Analysis Sample: 404"
#    base_intention    doses_2 doses_4 doses_6
# 1  Not at all likely NA      NA      NA
# 2  5                 NA       3       3
# 3  3                 NA      NA      NA
# 4  Not at all likely NA      NA       2
# 5  Not at all likely NA      NA      NA
# 6  Extremely likely  NA      NA       2
# 7  Extremely likely  NA      NA       3
# 8  Not at all likely NA       3       3
# 9  4                 NA      NA      NA
# 10 Extremely likely  NA       3       3
# 11 6                 NA      NA       3
# 12 2                 NA      NA       3
# 13 3                 NA      NA       3
# 14 Extremely likely  NA      NA      NA
# 15 5                 NA       3      NA
# 16 3                 NA      NA      NA
# 17 Not at all likely NA      NA      NA
# 18 5                 NA       3       2
# 19 4                 NA       2      NA
# ...

# %% [markdown]
# ### Remove people who gave inconsistent responses on vaccination questions

# %%
infeasible <- subset %>% filter(vaccinated_prior == TRUE, !is.na(intention_6)) %>% 
    filter(doses_2 >= 2 | doses_4 >= 2 | doses_6 >= 2) %>%
    dplyr::select(mturk_code, group, doses_2, doses_4, doses_6, 
                  intention_2, intention_4, intention_6, vaccinated_prior) %>%
    arrange(desc(doses_2), desc(doses_4), desc(doses_6)) 

subset <- subset %>% filter(!(mturk_code %in% infeasible$mturk_code))
paste0("Dropped for infeasible dose counts: ", nrow(infeasible), " (", 
       round(nrow(infeasible)/nrow(vcf_data),3), ")")
paste0("Analysis Sample: ", nrow(subset))
infeasible
# Out:
# [1] "Dropped for infeasible dose counts: 7 (0.014)"
# [1] "Analysis Sample: 397"
#   mturk_code group   doses_2 doses_4 doses_6 intention_2 intention_4
# 1 983103     Control 3        3       3      Vaccinated  Vaccinated
# 2 830458     Control 3        1       3      Vaccinated  Vaccinated
# 3 616612     Control 2        2       2      Vaccinated  Vaccinated
# 4 699737     Control 2        2       2      Vaccinated  Vaccinated
# 5 953099     Gist    2        2       2      Vaccinated  Vaccinated
# 6 311050     Gist    2       NA      NA      Vaccinated  5
# 7 645517     Gist    1        3       2      Vaccinated  Vaccinated
#   intention_6 vaccinated_prior
# 1 Vaccinated  TRUE
# 2 Vaccinated  TRUE
# 3 Vaccinated  TRUE
# 4 Vaccinated  TRUE
# 5 Vaccinated  TRUE
# 6 6           TRUE
# 7 Vaccinated  TRUE

# %%
vcf_data <- subset %>% filter(!is.na(sp_confidence_6))
paste0("Analysis Sample: ", nrow(vcf_data))
# Out:
# [1] "Analysis Sample: 397"

# %%
# Relabel the wave variable
vcf_data$wave <- "Wave 1"
vcf_data$wave[vcf_data$trial == 3] <- "Wave 2"
vcf_data$wave <- factor(vcf_data$wave, levels = c("Wave 1", "Wave 2"))

# Relabel the group variable
vcf_data$group <- vcf_data$group %>% as.character()
vcf_data$group[vcf_data$group == "Gist"] <- "Treatment"
vcf_data$group <- factor(vcf_data$group, levels = c("Treatment", "Control"))

# Baseline
vcf_data$base_intention_n <- vcf_data$base_intention %>% as.numeric()
vcf_data$base_encourage_n <- vcf_data$base_encourage %>% as.numeric()
vcf_data$base_sp_trust_n <- vcf_data$base_sp_trust %>% as.numeric()
vcf_data$base_sp_complacency_n <- vcf_data$base_sp_complacency %>% as.numeric()
vcf_data$base_sp_necessity_n <- vcf_data$base_sp_necessity %>% as.numeric()
vcf_data$base_sp_importance_n <- vcf_data$base_sp_importance %>% as.numeric()
vcf_data$base_sp_confidence_n <- vcf_data$base_sp_confidence %>% as.numeric()
vcf_data$base_sp_safety_n <- vcf_data$base_sp_safety %>% as.numeric()
vcf_data$base_sp_efficacy_n <- vcf_data$base_sp_efficacy %>% as.numeric()

# 6 week
vcf_data$intention_6_n <- vcf_data$intention_6 %>% as.numeric()
vcf_data$encourage_6_n <- vcf_data$encourage_6 %>% as.numeric()
vcf_data$sp_trust_6_n <- vcf_data$sp_trust_6 %>% as.numeric()
vcf_data$sp_complacency_6_n <- vcf_data$sp_complacency_6 %>% as.numeric()
vcf_data$sp_necessity_6_n <- vcf_data$sp_necessity_6 %>% as.numeric()
vcf_data$sp_importance_6_n <- vcf_data$sp_importance_6 %>% as.numeric()
vcf_data$sp_confidence_6_n <- vcf_data$sp_confidence_6 %>% as.numeric()
vcf_data$sp_safety_6_n <- vcf_data$sp_safety_6 %>% as.numeric()
vcf_data$sp_efficacy_6_n <- vcf_data$sp_efficacy_6 %>% as.numeric()

# Gist Items 
vcf_data$gist_cat1_6_n <- vcf_data$gist_cat1_6 %>% as.numeric()
vcf_data$gist_cat2_6_n <- vcf_data$gist_cat2_6 %>% as.numeric()
vcf_data$gist_cat3_6_n <- vcf_data$gist_cat3_6 %>% as.numeric()
vcf_data$gist_cat4_6_n <- vcf_data$gist_cat4_6 %>% as.numeric()
vcf_data$gist_cat5_6_n <- vcf_data$gist_cat5_6 %>% as.numeric()
vcf_data$gist_cat6_6_n <- vcf_data$gist_cat6_6 %>% as.numeric()
vcf_data$gist_cat7_6_n <- vcf_data$gist_cat7_6 %>% as.numeric()
vcf_data$gist_cat8_6_n <- vcf_data$gist_cat8_6 %>% as.numeric()

vcf_data$base_gist_cat1_n <- vcf_data$base_gist_cat1 %>% as.numeric()
vcf_data$base_gist_cat2_n <- vcf_data$base_gist_cat2 %>% as.numeric()
vcf_data$base_gist_cat3_n <- vcf_data$base_gist_cat3 %>% as.numeric()
vcf_data$base_gist_cat4_n <- vcf_data$base_gist_cat4 %>% as.numeric()
vcf_data$base_gist_cat5_n <- vcf_data$base_gist_cat5 %>% as.numeric()
vcf_data$base_gist_cat6_n <- vcf_data$base_gist_cat6 %>% as.numeric()
vcf_data$base_gist_cat7_n <- vcf_data$base_gist_cat7 %>% as.numeric()
vcf_data$base_gist_cat8_n <- vcf_data$base_gist_cat8 %>% as.numeric()

vcf_data$global1_6 <- factor(vcf_data$global1_6, levels = c("None", "Low", "Medium", "High"))
vcf_data$global2_6 <- factor(vcf_data$global2_6, levels = c("None", "Low", "Medium", "High"))                             
vcf_data$base_global1 <- factor(vcf_data$base_global1, levels = c("None", "Low", "Medium", "High"))                             
vcf_data$base_global2 <- factor(vcf_data$base_global2, levels = c("None", "Low", "Medium", "High"))                             
vcf_data$base_global1_n <- vcf_data$base_global1 %>% as.numeric()
vcf_data$base_global2_n <- vcf_data$base_global2 %>% as.numeric()
vcf_data$global1_6_n <- vcf_data$global1_6 %>% as.numeric()
vcf_data$global2_6_n <- vcf_data$global2_6 %>% as.numeric()

vcf_data <- vcf_data %>% 
    mutate(gist1_change = gist_cat1_6_n - base_gist_cat1_n,
           gist2_change = gist_cat2_6_n - base_gist_cat2_n,
           gist3_change = gist_cat3_6_n - base_gist_cat3_n,
           gist4_change = gist_cat4_6_n - base_gist_cat4_n,
           gist5_change = gist_cat5_6_n - base_gist_cat5_n,
           gist6_change = gist_cat6_6_n - base_gist_cat6_n,
           gist7_change = gist_cat7_6_n - base_gist_cat7_n,
           gist8_change = gist_cat8_6_n - base_gist_cat8_n,
           change_risk_princ = risk_princ_6 - base_risk_princ,
           change_resp_princ = resp_princ_6 - base_resp_princ
          )

# Cognitive Reasoning
vcf_data$crt_1_correct <- 0
vcf_data$crt_1_correct[vcf_data$crt_1 %in% 
                         c("500", "500 times", "Probability is half so 500 times")] <- 1
vcf_data$crt_2_correct <- 0
vcf_data$crt_2_correct[vcf_data$crt_2 %in% c("10")] <- 1
vcf_data$crt_3_correct <- 0
vcf_data$crt_3_correct[vcf_data$crt_3 %in% c("1", "1%", "1 percent")] <- 1
vcf_data$crt_sum <- vcf_data$crt_1_correct + vcf_data$crt_2_correct + vcf_data$crt_3_correct

vcf_data$crt_level <- NA
vcf_data$crt_level[vcf_data$crt_sum <= 1] <- "low"
vcf_data$crt_level[vcf_data$crt_sum > 1] <- "high"
vcf_data$crt_level <- factor(vcf_data$crt_level, levels = c("low", "high"))

paste0("Analysis sample: ", nrow(vcf_data))
# Out:
# [1] "Analysis sample: 397"

# %%
vcf_data$fed_gov_trust %>% table()
# Out:
# .
#     Not at all       A little Not applicable     Don't know   A great deal
#            209            142              0             12             34

# %% [markdown]
# ## ANCOVA Analysis Workflow
#
# https://mran.microsoft.com/web/packages/emmeans/vignettes/comparisons.html

# %% [markdown]
# ### Fit a model

# %%
options(repr.plot.width = 4, repr.plot.height = 4, repr.plot.res = 120)
vcf_data$gist_cat8_6_n %>% hist(main = "Raw Response")
# Out:
# Plot with title “Raw Response”

# %%
base_model <- aov(gist_cat8_6_n ~ group + wave + base_gist_cat8_n, data = vcf_data)
print(car::Anova(base_model, type = "III"))
# Out:
# Anova Table (Type III tests)
#
# Response: gist_cat8_6_n
#                  Sum Sq  Df  F value    Pr(>F)
# (Intercept)      144.87   1  66.6904 4.376e-15 ***
# group              5.64   1   2.5953    0.1080
# wave               2.81   1   1.2929    0.2562
# base_gist_cat8_n 552.40   1 254.2943 < 2.2e-16 ***
# Residuals        853.70 393
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
op <- par(pty = "s", mfrow = c(1, 2))
qqnorm(base_model$residuals, main = "QQ-Plot Fit to Transformed Scores")
qqline(base_model$residuals)
base_model$residuals %>% hist(main = "Residuals", freq = FALSE)
# Out:
# Plot with title “Residuals”

# %% [markdown]
# ### Calculate the optimal lambda for a Box-Cox transform

# %%
options(repr.plot.width = 6, repr.plot.height = 6, repr.plot.res = 100)
bc <- trafo::boxcox(base_model, method = "ml", lambdarange = c(-10, 3))
(lambda <- bc$lambdahat)
# Out:
# [1] 0.8308493
# plot without title

# %% [markdown]
# ### Fit a model using the Box-Cox transformed data

# %%
bctrans <- make.tran("boxcox", lambda)
model <- with(bctrans, 
              aov(linkfun(gist_cat8_6_n) ~ group + wave + linkfun(base_gist_cat8_n), data = vcf_data))
print(car::Anova(model, type = "III"))
# Out:
# Anova Table (Type III tests)
#
# Response: linkfun(gist_cat8_6_n)
#                           Sum Sq  Df  F value    Pr(>F)
# (Intercept)                91.59   1  63.5576 1.711e-14 ***
# group                       3.56   1   2.4714    0.1167
# wave                        1.79   1   1.2434    0.2655
# linkfun(base_gist_cat8_n) 365.36   1 253.5252 < 2.2e-16 ***
# Residuals                 566.36 393
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Plot the expected marginal means

# %%
emm_base <- emmeans(base_model, "group")

options(repr.plot.width = 8, repr.plot.height = 6, repr.plot.res = 120)
plot(emm_base, comparisons = TRUE) + labs(x = "Expected Marginal Mean (Original Values)", y = "")
# Out:
# plot without title

# %%
emm_back <- emmeans(model, "group", type = "response")
options(repr.plot.width = 8, repr.plot.height = 6, repr.plot.res = 120)
suppressWarnings(plot(emm_back, comparisons = TRUE) + 
                 labs(x = "Expected Marginal Mean (Back Transformed)", y = ""))
# Out:
# plot without title

# %% [markdown]
# ### Calcualte the difference between expected marginal means

# %%
emm_diff_base <- suppressWarnings(pairs(emm_base))
emm_diff_base
# Out:
#  contrast            estimate   SE  df t.ratio p.value
#  Treatment - Control    0.242 0.15 393   1.611  0.1080
#
# Results are averaged over the levels of: wave

# %%
rg <- ref_grid(model, "group")
emm_diff_back <- pairs(emmeans(regrid(rg, transform = "response"), "group"))
print(emm_diff_back)
# Out:
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control    0.241 0.153 393   1.574  0.1164
#
# Results are averaged over the levels of: wave

# %% [markdown]
# ### Calculate 95% CI for Difference in Expected Marginal Means

# %%
emm_diff_base %>% confint() %>% print()
# Out:
#  contrast            estimate   SE  df lower.CL upper.CL
#  Treatment - Control    0.242 0.15 393  -0.0533    0.537
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95

# %%
emm_diff_back %>% confint() %>% print()
# Out:
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control    0.241 0.153 393  -0.0601    0.542
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95

# %%
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
op <- par(pty = "s", mfrow = c(1, 2))
qqnorm(base_model$residuals, main = "QQ-Plot Fit to Transformed Scores")
qqline(base_model$residuals)
base_model$residuals %>% hist(main = "Residuals", freq = FALSE)
# Out:
# Plot with title “Residuals”

# %%
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
op <- par(pty = "s", mfrow = c(1, 2))
qqnorm(model$residuals, main = "QQ-Plot Fit to Transformed Scores")
qqline(model$residuals)
model$residuals %>% hist(main = "Residuals", freq = FALSE)
# Out:
# Plot with title “Residuals”

# %% [markdown]
# ## Modularize Code

# %%
# ANCOVA using a Box-Cox Transformation
get_emm_diff_bc <- function(data, label, method = "ml"){
    # fit base model
    model <- aov(post ~ group + wave + pre, data = data) 
    
    # plot estimated marginal means
    emm <- emmeans(model, "group")
    print(emm)   
    
    # calculate differences in expected marginal means
    emm_diff <- suppressWarnings(pairs(emm))
    print(emm_diff)
    
    # calculate 95% CI for difference in expected marginal means
    ci <- emm_diff %>% confint()
    print(ci)
    
    # assemble results
    mean <- ci$estimate
    low <- ci$lower.CL
    high <- ci$upper.CL
    p <- summary(emm_diff)$p.value    
    ci_summary <- paste0("mean = ", round(mean, 3), 
                         "; 95% CI = ", round(low, 3), ", ", round(high, 3), 
                         "; P = ", round(p, 4))
    plot_points <- tibble(x = c(low, mean, high), label = label)
    return(list(
        "base_model" = base_model,
        "lambda" = lambda,
        "model" = model,
        "CI" = ci_summary,
        "plot_points" = plot_points))
}

get_pre_post_means <- function(data, label){
    data <- data %>% filter(!is.na(post))
    tbl <- data %>% group_by(group) %>%
        summarise(N = n(),
                  baseline = paste0(round(mean(pre),2), " (", round(sd(pre), 2), ")"),
                  `6_wk` = paste0(round(mean(post),2), " (", round(sd(post), 2), ")"),
                  mean_diff = paste0(round(mean(post-pre),3), " (", round(sd(post-pre), 2), ")"))
    tbl$p <- c(round(wilcox.test(data$post[data$group == "Treatment"], data$pre[data$group == "Treatment"], paired = TRUE, var.equal = TRUE, alternative = "greater")$p.value, 6),
               round(wilcox.test(data$post[data$group == "Control"], data$pre[data$group == "Control"], paired = TRUE, var.equal = TRUE, alternative = "greater")$p.value, 6))
    tbl$label <- label
    tbl <- tbl %>% dplyr::select(label, group, N, baseline, `6_wk`, mean_diff, p)
    tbl
}

plot_qqs_hist <- function(object){
    op <- par(pty = "s", mfrow = c(1, 2))
    qqnorm(object$model$residuals, main = "QQ-Plot")
    qqline(object$model$residuals)
    object$model$residuals %>% hist(main = "Residuals", freq = FALSE)
}

# %% [markdown]
# ### Calculate results for each outcome

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat8_n, 
                                              post = gist_cat8_6_n), 
                                              label = "Gist Cat 8 (Death/Hosp Risk)")

gist8 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat8_6_n, group, wave, pre = base_gist_cat8_n),   
                             method = "ml", label =  "Gist Cat 8 (Death/Hosp Risk)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist8)
# Out:
#   label                        group     N   baseline    6_wk
# 1 Gist Cat 8 (Death/Hosp Risk) Treatment 220 3.61 (1.73) 4.01 (1.91)
# 2 Gist Cat 8 (Death/Hosp Risk) Control   177 3.47 (1.75) 3.69 (1.87)
#   mean_diff    p
# 1 0.395 (1.62) 0.000194
# 2 0.22 (1.51)  0.009053
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   3.94 0.102 393     3.74     4.14
#  Control     3.70 0.119 393     3.46     3.93
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate   SE  df t.ratio p.value
#  Treatment - Control    0.242 0.15 393   1.611  0.1080
#
# Results are averaged over the levels of: wave
#  contrast            estimate   SE  df lower.CL upper.CL
#  Treatment - Control    0.242 0.15 393  -0.0533    0.537
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat7_n, 
                                              post = gist_cat7_6_n), 
                                              label = "Gist Cat 7 (Risks Add Up)")

gist7 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat7_6_n, group, wave, pre = base_gist_cat7_n),   
                             method = "ml", label =  "Gist Cat 7 (Risks Add Up)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist7)
# Out:
#   label                     group     N   baseline    6_wk        mean_diff
# 1 Gist Cat 7 (Risks Add Up) Treatment 220 3.47 (1.69) 3.86 (1.89) 0.391 (1.74)
# 2 Gist Cat 7 (Risks Add Up) Control   177 3.48 (1.66) 3.89 (1.84) 0.412 (1.86)
#   p
# 1 0.000825
# 2 0.000754
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   3.85 0.113 393     3.62     4.07
#  Control     3.86 0.132 393     3.60     4.12
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control  -0.0143 0.166 393  -0.086  0.9315
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control  -0.0143 0.166 393   -0.341    0.313
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat6_n, 
                                              post = gist_cat6_6_n), 
                                              label = "Gist Cat 6 (Risks Add Up)")

gist6 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat6_6_n, group, wave, pre = base_gist_cat6_n),   
                             method = "ml", label =  "Gist Cat 6 (Risks Add Up)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist6)
# Out:
#   label                     group     N   baseline    6_wk        mean_diff
# 1 Gist Cat 6 (Risks Add Up) Treatment 220 2.99 (1.58) 3.57 (1.77) 0.582 (1.6)
# 2 Gist Cat 6 (Risks Add Up) Control   177 3.14 (1.55) 3.62 (1.77) 0.486 (1.79)
#   p
# 1 0.000000
# 2 0.000253
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   3.60 0.107 393     3.39     3.81
#  Control     3.56 0.124 393     3.32     3.80
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   0.0392 0.157 393   0.250  0.8028
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   0.0392 0.157 393   -0.269    0.348
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat5_n, 
                                              post = gist_cat5_6_n), 
                                              label = "Gist 5 (Low Risks Happen)")

gist5 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat5_6_n, group, wave, pre = base_gist_cat5_n),   
                             method = "ml", label =  "Gist 5 (Low Risks Happen)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist5)
# Out:
#   label                     group     N   baseline   6_wk        mean_diff
# 1 Gist 5 (Low Risks Happen) Treatment 220 5.7 (1.41) 5.67 (1.55) -0.036 (1.51)
# 2 Gist 5 (Low Risks Happen) Control   177 5.83 (1.2) 5.84 (1.3)  0.006 (1.42)
#   p
# 1 0.495325
# 2 0.366920
#  group     emmean     SE  df lower.CL upper.CL
#  Treatment   5.68 0.0906 393     5.50     5.86
#  Control     5.78 0.1049 393     5.57     5.98
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   -0.096 0.133 393  -0.724  0.4694
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   -0.096 0.133 393   -0.357    0.165
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat4_n, 
                                              post = gist_cat4_6_n), 
                                              label = "Gist 4 (Only Takes Once)")

gist4 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat4_6_n, group, wave, pre = base_gist_cat4_n),   
                             method = "ml", label =  "Gist 4 (Only Takes Once)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist4)
# Out:
#   label                    group     N   baseline    6_wk        mean_diff
# 1 Gist 4 (Only Takes Once) Treatment 220 4.79 (1.57) 4.92 (1.78) 0.132 (1.69)
# 2 Gist 4 (Only Takes Once) Control   177 4.86 (1.62) 5.15 (1.69) 0.288 (1.64)
#   p
# 1 0.089650
# 2 0.004141
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   4.92 0.105 393     4.71     5.13
#  Control     5.10 0.122 393     4.86     5.34
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   -0.179 0.154 393  -1.167  0.2438
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   -0.179 0.154 393   -0.481    0.123
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat3_n, 
                                              post = gist_cat3_6_n), 
                                              label = "Gist 3 (No Second Chance)")

gist3 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat3_6_n, group, wave, pre = base_gist_cat3_n),   
                             method = "ml", label =  "Gist 3 (No Second Chance)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist3)
# Out:
#   label                     group     N   baseline    6_wk     mean_diff
# 1 Gist 3 (No Second Chance) Treatment 220 2.74 (1.65) 3.08 (2) 0.341 (1.75)
# 2 Gist 3 (No Second Chance) Control   177 2.85 (1.83) 3.31 (2) 0.458 (1.85)
#   p
# 1 0.004051
# 2 0.000458
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   3.09 0.117 393     2.86     3.32
#  Control     3.23 0.135 393     2.97     3.50
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   -0.143 0.171 393  -0.836  0.4034
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   -0.143 0.171 393   -0.479    0.193
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat2_n, 
                                              post = gist_cat2_6_n), 
                                              label = "Gist 2 (Only Takes Once)")

gist2 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat2_6_n, group, wave, pre = base_gist_cat2_n),   
                             method = "ml", label =  "Gist 2 (Only Takes Once)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist2)
# Out:
#   label                    group     N   baseline    6_wk        mean_diff
# 1 Gist 2 (Only Takes Once) Treatment 220 4.85 (1.65) 4.97 (1.81) 0.123 (1.65)
# 2 Gist 2 (Only Takes Once) Control   177 5.07 (1.56) 5.41 (1.6)  0.339 (1.87)
#   p
# 1 0.094867
# 2 0.003460
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   5.00 0.107 393     4.79     5.21
#  Control     5.32 0.124 393     5.07     5.56
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   -0.317 0.157 393  -2.022  0.0439
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   -0.317 0.157 393   -0.625  -0.0087
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat1_n, 
                                              post = gist_cat1_6_n), 
                                              label = "Gist 1 (Low Risks Happen)")

gist1 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat1_6_n, group, wave, pre = base_gist_cat1_n),   
                             method = "ml", label =  "Gist 1 (Low Risks Happen)")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist1)
# Out:
#   label                     group     N   baseline    6_wk        mean_diff
# 1 Gist 1 (Low Risks Happen) Treatment 220 5.31 (1.25) 5.42 (1.36) 0.114 (1.46)
# 2 Gist 1 (Low Risks Happen) Control   177 5.53 (1.13) 5.62 (1.24) 0.09 (1.34)
#   p
# 1 0.095506
# 2 0.135409
#  group     emmean     SE  df lower.CL upper.CL
#  Treatment   5.45 0.0848 393     5.29     5.62
#  Control     5.55 0.0983 393     5.36     5.75
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control  -0.0998 0.124 393  -0.802  0.4229
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control  -0.0998 0.124 393   -0.344    0.145
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_global1_n, 
                                              post = global1_6_n), 
                                              label = "Global 1")

global1 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = global1_6_n, group, wave, pre = base_global1_n),   
                             method = "ml", label =  "Global 1")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(global1)
# Out:
#   label    group     N   baseline    6_wk        mean_diff     p
# 1 Global 1 Treatment 220 2.34 (0.72) 2.26 (0.68) -0.073 (0.65) 0.948152
# 2 Global 1 Control   177 2.33 (0.68) 2.24 (0.68) -0.09 (0.62)  0.972781
#  group     emmean     SE  df lower.CL upper.CL
#  Treatment   2.26 0.0388 393     2.18     2.33
#  Control     2.24 0.0450 393     2.15     2.32
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate     SE  df t.ratio p.value
#  Treatment - Control   0.0224 0.0568 393   0.394  0.6939
#
# Results are averaged over the levels of: wave
#  contrast            estimate     SE  df lower.CL upper.CL
#  Treatment - Control   0.0224 0.0568 393  -0.0893    0.134
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
get_pre_post_means(data = vcf_data %>% mutate(pre = base_global2_n, 
                                              post = global2_6_n), 
                                              label = "Global 2")

global2 <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = global2_6_n, group, wave, pre = base_global2_n),   
                             method = "ml", label =  "Global 1")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(global2)
# Out:
#   label    group     N   baseline    6_wk        mean_diff     p
# 1 Global 2 Treatment 220 2.24 (0.7)  2.3 (0.77)  0.064 (0.74)  0.096241
# 2 Global 2 Control   177 2.32 (0.75) 2.23 (0.65) -0.085 (0.68) 0.964892
#  group     emmean     SE  df lower.CL upper.CL
#  Treatment   2.34 0.0429 393     2.25     2.42
#  Control     2.24 0.0497 393     2.14     2.33
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate     SE  df t.ratio p.value
#  Treatment - Control    0.101 0.0628 393   1.604  0.1096
#
# Results are averaged over the levels of: wave
#  contrast            estimate     SE  df lower.CL upper.CL
#  Treatment - Control    0.101 0.0628 393  -0.0228    0.224
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
plot_df <- bind_rows(gist8$plot_points %>% mutate(y = 1, label = "Gist 8 (Death/Hosp Risk)"),
                     gist7$plot_points %>% mutate(y = 2, label = "Gist 7 (Risks Add Up)"),
                     gist6$plot_points %>% mutate(y = 3, label = "Gist 6 (Risks Add Up)"),
                     gist5$plot_points %>% mutate(y = 4, label = "Gist 5 (Low Risks Happen)"),
                     gist4$plot_points %>% mutate(y = 5, label = "Gist 4 (Only Takes Once)"),
                     gist3$plot_points %>% mutate(y = 6, label = "Gist 3 (No Second Chance)"),
                     gist2$plot_points %>% mutate(y = 7, label = "Gist 2 (Only Takes Once)"),
                     gist1$plot_points %>% mutate(y = 8, label = "Gist 1 (Low Risks Happen)"),
                     global1$plot_points %>% mutate(y = 0, label = "Global 1 (Risk of Getting)"),
                     global2$plot_points %>% mutate(y = -1, label = "Global 2 (Risk of Spreading)")
                     )
plot_df_means <- plot_df[seq(2, nrow(plot_df), by = 3),]
labels <- plot_df$label %>% unique()
breaks <- plot_df$y %>% unique()

options(repr.plot.width = 10, repr.plot.height = 8, repr.plot.res = 150)
ggplot(data = plot_df,
       mapping = aes(x = x, y = y)) +
  geom_line(data = plot_df,
            mapping = aes(x = x, y = y, group = label, color = "black")) +
  geom_point(data = plot_df_means,
             mapping = aes(x = x, y = y, group = label, color = "black"), 
             shape = 21, size = 3, fill = "black") +
  theme_minimal() +
    scale_color_manual(values = "black") +       
    scale_y_continuous(
      breaks = breaks,
      labels = labels) +
    labs(
      x = "",
      y = " ",
      title = "Difference in Expected Gist Endorsement \n Between Experimental Groups (95% CI)") +
    geom_vline(xintercept =  0, color = "darkgray", linewidth = 1) +
    geom_vline(xintercept =  -0.25, color = "lightgray") +
    geom_vline(xintercept =  0.25, color = "lightgray") +
    theme( 
          panel.grid.major.x = element_blank(),
          panel.grid.minor.x = element_blank(),
          panel.grid.major.y = element_blank(),
          panel.grid.minor.y = element_blank(),
          axis.text.x = element_text(size = 14, color= "black"),
          axis.text.y = element_text(size = 14),
          title = element_text(size = 14)) +
    #theme(panel.border=element_rect(linetype=1,fill=NA)) +
    guides(color = "none") +
    theme(plot.title = element_text(hjust = 0.5))# +
#  xlim(-0.25, 0.35)
# Out:
# plot without title

# %%
bind_rows(
      tibble(measure = "Gist 1 (Low Risks Happen)", CI = gist1$CI),
      tibble(measure = "Gist 2 (Only Takes Once)", CI = gist2$CI),
      tibble(measure = "Gist 3 (No Second Chance)", CI = gist3$CI),
      tibble(measure = "Gist 4 (Only Takes Once)", CI = gist4$CI),
      tibble(measure = "Gist 5 (Low Risks Happen)", CI = gist5$CI),
      tibble(measure = "Gist 6 (Risks Add Up)", CI = gist6$CI),
      tibble(measure = "Gist 7 (Risks Add Up)", CI = gist7$CI),
      tibble(measure = "Gist 8 (Death/Hosp Risk)", CI = gist8$CI),
      tibble(measure = "Global 1 (Risk of Getting COVID-19)", CI = global1$CI),
      tibble(measure = "Global 2 (Risk of Spreading)", CI = global2$CI)) %>%
    mutate(print = paste0(measure, " (", CI, ")")) %>%.$print %>% print()
# Out:
#  [1] "Gist 1 (Low Risks Happen) (mean = -0.1; 95% CI = -0.344, 0.145; P = 0.4229)"
#  [2] "Gist 2 (Only Takes Once) (mean = -0.317; 95% CI = -0.625, -0.009; P = 0.0439)"
#  [3] "Gist 3 (No Second Chance) (mean = -0.143; 95% CI = -0.479, 0.193; P = 0.4034)"
#  [4] "Gist 4 (Only Takes Once) (mean = -0.179; 95% CI = -0.481, 0.123; P = 0.2438)"
#  [5] "Gist 5 (Low Risks Happen) (mean = -0.096; 95% CI = -0.357, 0.165; P = 0.4694)"
#  [6] "Gist 6 (Risks Add Up) (mean = 0.039; 95% CI = -0.269, 0.348; P = 0.8028)"
#  [7] "Gist 7 (Risks Add Up) (mean = -0.014; 95% CI = -0.341, 0.313; P = 0.9315)"
#  [8] "Gist 8 (Death/Hosp Risk) (mean = 0.242; 95% CI = -0.053, 0.537; P = 0.108)"
#  [9] "Global 1 (Risk of Getting COVID-19) (mean = 0.022; 95% CI = -0.089, 0.134; P = 0.6939)"
# [10] "Global 2 (Risk of Spreading) (mean = 0.101; 95% CI = -0.023, 0.224; P = 0.1096)"

# %% [markdown]
# ## Average Gist Measures

# %%
vcf_data$gist_cat_6 <- as.numeric(vcf_data$gist_cat1_6) + as.numeric(vcf_data$gist_cat2_6) + 
                       as.numeric(vcf_data$gist_cat3_6) + as.numeric(vcf_data$gist_cat4_6) + 
                       as.numeric(vcf_data$gist_cat5_6) + as.numeric(vcf_data$gist_cat6_6) + 
                       as.numeric(vcf_data$gist_cat7_6) + as.numeric(vcf_data$gist_cat8_6) 

vcf_data$base_gist_cat <- as.numeric(vcf_data$base_gist_cat1) + as.numeric(vcf_data$base_gist_cat2) + 
                          as.numeric(vcf_data$base_gist_cat3) + as.numeric(vcf_data$base_gist_cat4) + 
                          as.numeric(vcf_data$base_gist_cat5) + as.numeric(vcf_data$base_gist_cat6) + 
                          as.numeric(vcf_data$base_gist_cat7) + as.numeric(vcf_data$base_gist_cat8) 

get_pre_post_means(data = vcf_data %>% mutate(pre = base_gist_cat, 
                                              post = gist_cat_6), 
                                              label = "Avg Cat Risk")

gist_cat <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = gist_cat_6, group, wave, pre = base_gist_cat),   
                             method = "ml", label =  "Avg Cat Risk")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist_cat)
# Out:
#   label        group     N   baseline     6_wk         mean_diff    p
# 1 Avg Cat Risk Treatment 220 33.46 (8.16) 35.5 (10.42) 2.041 (8.09) 3e-06
# 2 Avg Cat Risk Control   177 34.22 (7.7)  36.52 (9.19) 2.299 (7.55) 3e-06
#  group     emmean    SE  df lower.CL upper.CL
#  Treatment   35.7 0.534 393     34.6     36.7
#  Control     36.0 0.619 393     34.8     37.2
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control   -0.356 0.782 393  -0.455  0.6495
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control   -0.356 0.782 393    -1.89     1.18
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
vcf_data$global_6 <- as.numeric(vcf_data$global1_6) + as.numeric(vcf_data$global2_6)
vcf_data$base_global <- as.numeric(vcf_data$base_global1) + as.numeric(vcf_data$base_global2) 

gist_ord <- get_emm_diff_bc(data = vcf_data %>% 
                             dplyr::select(post = global_6, group, wave, pre = base_global),   
                             method = "ml", label =  "Avg Ord Risk")
options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 120)
plot_qqs_hist(gist_ord)
# Out:
#  group     emmean     SE  df lower.CL upper.CL
#  Treatment   4.60 0.0738 393     4.45     4.74
#  Control     4.47 0.0856 393     4.30     4.64
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
#  contrast            estimate    SE  df t.ratio p.value
#  Treatment - Control    0.129 0.108 393   1.196  0.2324
#
# Results are averaged over the levels of: wave
#  contrast            estimate    SE  df lower.CL upper.CL
#  Treatment - Control    0.129 0.108 393  -0.0832    0.342
#
# Results are averaged over the levels of: wave
# Confidence level used: 0.95
# Plot with title “Residuals”

# %%
save(vcf_data, file = "~/Documents/holding_gwu_dissertation/data/vcf_data_for_python.RData")

# %% [markdown]
# ### 2-way ANOVA in R

# %%
library(rstatix)
pre = vcf_data %>% dplyr::select(id = participant_id, group, score = base_gist_cat) %>% mutate(time = "pretest")
post = vcf_data %>% dplyr::select(id = participant_id, group, score = gist_cat_6) %>% mutate(time = "posttest")
df = bind_rows(pre, post)
df$time <- factor(df$time, levels = c("pretest", "posttest"))
df$group <- factor(df$group, levels = c("Control", "Treatment"))

df %>%
  group_by(time, group) %>%
  summarise(mean = mean(score),
            sd = sd(score))

res.aov <- anova_test(
  data = df, dv = score, wid = id,
  between = group, within = time
  )
get_anova_table(res.aov)
# Out:
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# `summarise()` has grouped output by 'time'. You can override using the
# `.groups` argument.
#   time     group     mean     sd
# 1 pretest  Control   34.22034  7.701242
# 2 pretest  Treatment 33.45909  8.160667
# 3 posttest Control   36.51977  9.185024
# 4 posttest Treatment 35.50000 10.424550
#   Effect     DFn DFd F      p        p<.05 ges
# 1 group      1   395  1.193 2.75e-01       2.00e-03
# 2 time       1   395 29.960 7.85e-08 *     1.40e-02
# 3 group:time 1   395  0.106 7.45e-01       5.15e-05

# %%
df %>%
  group_by(time, group) %>%
  shapiro_test(score)
# Out:
#   group     time     variable statistic p
# 1 Control   pretest  score    0.9909852 0.3317492063
# 2 Treatment pretest  score    0.9809778 0.0046112466
# 3 Control   posttest score    0.9729732 0.0016112900
# 4 Treatment posttest score    0.9733561 0.0003588793

# %%
library(ggpubr)
ggqqplot(df, "score", ggtheme = theme_bw()) +
  facet_grid(time ~ group)
# Out:
# Warning message:
# “The following aesthetics were dropped during statistical transformation: sample
# ℹ This can happen when ggplot fails to infer the correct grouping structure in
#   the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical
#   variable into a factor?”
# Warning message:
# “The following aesthetics were dropped during statistical transformation: sample
# ℹ This can happen when ggplot fails to infer the correct grouping structure in
#   the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical
#   variable into a factor?”
# Warning message:
# “The following aesthetics were dropped during statistical transformation: sample
# ℹ This can happen when ggplot fails to infer the correct grouping structure in
#   the data.
# ℹ Did you forget to specify a `group` aesthetic or to convert a numerical
#   variable into a factor?”
# Warning message:
# ...

# %%
bxp <- ggboxplot(
  df, x = "time", y = "score",
  color = "group", palette = "jco"
  )
bxp
# Out:
# plot without title

# %%
library(afex)
# Out:
# Loading required package: lme4
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# ************
# Welcome to afex. For support visit: http://afex.singmann.science/
#
# - Functions for ANOVAs: aov_car(), aov_ez(), and aov_4()
# - Methods for calculating p-values with mixed(): 'S', 'KR', 'LRT', and 'PB'
# - 'afex_aov' and 'mixed' objects can be passed to emmeans() for follow-up tests
# - NEWS: emmeans() for ANOVA models now uses model = 'multivariate' as default.
# - Get and set global package options with: afex_options()
# - Set orthogonal sum-to-zero contrasts globally: set_sum_contrasts()
# - For example analyses see: browseVignettes("afex")
# ************
#
#
# Attaching package: ‘afex’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer

# %%
mixed_anova <- aov_ez(
  id = "id",
  dv = "score",
  data = df,
  between = "group",
  within = "time"
)
# Out:
# Contrasts set to contr.sum for the following variables: group

# %%
mixed_anova
# Out:
# Anova Table (Type 3 tests)
#
# Response: score
#       Effect     df    MSE         F   ges p.value
# 1      group 1, 395 130.35      1.19  .002    .275
# 2       time 1, 395  30.84 29.96 ***  .014   <.001
# 3 group:time 1, 395  30.84      0.11 <.001    .745
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘+’ 0.1 ‘ ’ 1

# %%
afex_plot(mixed_anova, x = "time", trace = "group")
# Out:
# Warning message:
# “Panel(s) show a mixed within-between-design.
# Error bars do not allow comparisons across all means.
# Suppress error bars with: error = "none"”
# plot without title

# %%
mixed_anova$lm$residuals %>% hist()
# Out:
# Plot with title “Histogram of .”

# %%
res <- aov(score ~ group*time + Error(id/time) + group, data = df)
summary(res)
# Out:
# Error: id
#            Df Sum Sq Mean Sq F value Pr(>F)
# group       1    156   155.6   1.193  0.275
# Residuals 395  51489   130.3
#
# Error: id:time
#             Df Sum Sq Mean Sq F value   Pr(>F)
# time         1    923   922.8  29.926 7.98e-08 ***
# group:time   1      3     3.3   0.106    0.745
# Residuals  395  12181    30.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
op <- par(pty = "s", mfrow = c(1, 2))
qqnorm(res$id$residuals, main = "QQ-Plot")
qqline(res$id$residuals)
res$id$residuals %>% hist(main = "Residuals", freq = FALSE)
# Out:
# Plot with title “Residuals”
